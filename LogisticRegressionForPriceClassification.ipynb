# %% [markdown]
# <a href="https://colab.research.google.com/github/inixrust/datasets/blob/main/LogisticRegressionForPriceClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate https://raw.githubusercontent.com/inixrust/datasets/main/housing.csv
# Out:
# --2024-09-03 07:39:45--  https://raw.githubusercontent.com/inixrust/datasets/main/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]   1.36M  --.-KB/s    in 0.08s
#
# 2024-09-03 07:39:45 (17.0 MB/s) - ‘housing.csv’ saved [1423529/1423529]

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('/content/housing.csv')

housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6656     -118.13     34.15                18.0       1665.0           477.0
# 12922    -121.32     38.66                21.0       1276.0           208.0
# 7600     -118.25     33.89                34.0       1367.0           288.0
# 20321    -119.16     34.23                26.0       5444.0          1293.0
# 19518    -121.01     37.64                33.0        693.0           207.0
#
#        population  households  median_income  median_house_value  \
# 6656       1095.0       390.0         2.6038            155600.0
# 12922       501.0       205.0         3.9500            143600.0
# 7600       1183.0       286.0         2.6812            104100.0
# 20321      3700.0      1158.0         2.7556            213200.0
# 19518       598.0       192.0         1.0217             81300.0
#
#       ocean_proximity
# 6656        <1H OCEAN
# 12922          INLAND
# 7600        <1H OCEAN
# 20321      NEAR OCEAN
# ...

# %%
housing_data = housing_data.dropna()

# %%
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing_data.loc[housing_data['median_house_value'] == 500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %%
housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value'] == 500001].index)

# %%
housing_data.shape
# Out:
# (19475, 10)

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
housing_data = pd.get_dummies(housing_data, columns=['ocean_proximity'])

# %%
housing_data.shape
# Out:
# (19475, 14)

# %%
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3310     -122.63     38.94                18.0       3844.0           969.0
# 14226    -117.05     32.68                15.0       1828.0           359.0
# 2339     -119.67     36.82                 2.0       2579.0           376.0
# 1548     -121.94     37.75                17.0       2559.0           370.0
# 14645    -117.19     32.77                30.0       2747.0           640.0
#
#        population  households  median_income  median_house_value  \
# 3310       1832.0       845.0         1.1250             81800.0
# 14226       955.0       248.0         3.2174            165100.0
# 2339       1133.0       342.0         4.5577            123300.0
# 1548       1238.0       377.0         6.2781            269800.0
# 14645      3185.0       657.0         3.7650            238000.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# ...

# %%
median = housing_data['median_house_value'].median()

median
# Out:
# 173800.0

# %%
housing_data['above_median'] = (housing_data['median_house_value'] - median) > 0

# %%
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16708    -120.57     35.18                16.0       5209.0           917.0
# 9698     -121.61     36.67                39.0       3260.0           821.0
# 4413     -118.25     34.08                47.0       2133.0           689.0
# 6877     -118.10     34.07                36.0       3661.0           956.0
# 19248    -122.74     38.47                16.0       1426.0           287.0
#
#        population  households  median_income  median_house_value  \
# 16708      2284.0       809.0         4.0403            346100.0
# 9698       3130.0       793.0         2.5224            119200.0
# 4413       2104.0       662.0         2.6136            169200.0
# 6877       3816.0       931.0         2.5104            185000.0
# 19248       525.0       260.0         3.0714            161700.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# ...

# %%
X = housing_data.drop(['median_house_value', 'above_median'], axis=1)
Y = housing_data['above_median']

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
y_train.shape, y_test.shape
# Out:
# ((15580,), (3895,))

# %% [markdown]
# ### Train a logistic regression model for price classification

# %%
from sklearn.linear_model import LogisticRegression

logistic_model = LogisticRegression(solver='liblinear').fit(x_train, y_train)

# %%
print("Training_score : " , logistic_model.score(x_train, y_train))
# Out:
# Training_score :  0.8206033376123235

# %%
y_pred = logistic_model.predict(x_test)

# %%
df_pred_actual = pd.DataFrame({'predicted': y_pred, 'actual': y_test})

df_pred_actual.head(10)
# Out:
#        predicted  actual
# 3281       False   False
# 14819      False   False
# 16272      False   False
# 17842       True    True
# 20225      False   False
# 8674       False    True
# 6940        True   False
# 7930        True   False
# 15577       True   False
# 7875        True   False

# %%
from sklearn.metrics import accuracy_score

print("Testing_score : ", accuracy_score(y_test, y_pred))
# Out:
# Testing_score :  0.8182284980744544
